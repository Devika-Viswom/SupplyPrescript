# %%
import pandas as pd

# %%
data_path = "../data"

# %%
df_final=pd.read_pickle(data_path+"/processed/df_final.pkl")

# %%
df_final.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Origin_Port                5000 non-null   str
#  1   Destination_Port           5000 non-null   str
#  2   Transport_Mode             5000 non-null   str
#  3   Product_Category           5000 non-null   str
#  4   Distance_km                5000 non-null   float64
#  5   Weight_MT                  5000 non-null   float64
#  6   Fuel_Price_Index           5000 non-null   float64
#  7   Geopolitical_Risk_Score    5000 non-null   float64
#  8   Weather_Condition          5000 non-null   str
#  9   Carrier_Reliability_Score  5000 non-null   float64
#  10  Lead_Time_Days             5000 non-null   float64
#  11  Disruption_Occurred        5000 non-null   int64
#  12  Year                       5000 non-null   int32
#  13  Month                      5000 non-null   int32
# ...

# %%
df_clf = df_final.drop(
    columns=["Lead_Time_Days"]
)

df_reg = df_final.drop(
    columns=["Disruption_Occurred"]
)

# %%
X_clf = df_clf.drop(
    columns=["Disruption_Occurred"]
)

y_clf = df_clf["Disruption_Occurred"]

# %%
X_reg = df_reg.drop(
    columns=["Lead_Time_Days"]
)

y_reg = df_reg["Lead_Time_Days"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train_clf, X_test_clf, y_train_clf, y_test_clf = train_test_split(
    X_clf,
    y_clf,
    test_size=0.2,
    random_state=42,
    stratify=y_clf
)

# %%
X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(
    X_reg,
    y_reg,
    test_size=0.2,
    random_state=42
)

# %%
categorical_cols = [
    "Origin_Port",
    "Destination_Port",
    "Transport_Mode",
    "Product_Category",
    "Weather_Condition",
    "Route",
    "Risk_Level",
    "Reliability_Level"
]

numeric_cols = [
    "Distance_km",
    "Weight_MT",
    "Fuel_Price_Index",
    "Geopolitical_Risk_Score",
    "Carrier_Reliability_Score",
    "Year",
    "Month",
    "Quarter"
]
